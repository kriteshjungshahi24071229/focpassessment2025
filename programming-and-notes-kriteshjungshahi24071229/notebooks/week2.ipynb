# %% [markdown]
# # Week 2 - Variables And Types

# %% [markdown]
# # Objectives
# To understand variables and assignment
# To learn different data types in Python
# To use print and input functions
# To manipulate strings
# To get an introduction to lists
#
# # Concepts Covered
# Variables and identifiers
# Integer, float, string, and boolean data types
# print() function
# User input using input()
# String manipulation
# Introduction to lists

# %% [markdown]
# Example 1 : Variables And Data Types

# %%
age = 20
height = 5.6
name = "Kritesh"
is_student = True

print(age)
print(height)
print(name)
print(is_student)

# %% [markdown]
# Example 2 : Getting Input From User

# %%
user_name = input("Enter your name: ")
print("Welcome,", user_name)

# %% [markdown]
# Example 3: String Manipulation

# %%
text = "Fundamentals of Programming"
print(text.upper())
print(text.lower())
print(len(text))

# %% [markdown]
# Example 4: Introduction to Lists

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers)
print(numbers[0])

# %% [markdown]
# # Reflection

# %% [markdown]
# In this week, I learned how data is stored using variables and how different data types work in Python. Using print() and taking input from the user helped me see how programs interact with users. I found string manipulation interesting, although remembering different string methods took some practice.
