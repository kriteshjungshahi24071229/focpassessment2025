# %% [markdown]
# # Week 1 - Introduction To Programming

# %% [markdown]
# # Objectives
# To understand what a computer program is
# Learn different types of programming languages
# Get an overview of python
# Understand expression and basic errors
#
# # Concepts covered
# What a computer program is
# Types of programming languages
# Development tools
# Expressions and errors

# %% [markdown]
# Example 1: Simple Python Expression

# %%
10 * 2 + (4 / 2.5 * 2)

# %% [markdown]
# Example 2: Printing Output

# %%
print("Hello, World!")
print("Python is easy to learn")

# %% [markdown]
# Example 3 : Common Error Example

# %% [markdown]
# # This will cause an error because quotes are missing
# # print(Hello)

# %% [markdown]
# # Reflection

# %% [markdown]
# This week helped me understand what programming actually is and how programs work step by step. Learning about different types of programming languages and why Python is used made the subject feel less confusing. I also became familiar with basic expressions and common errors, which helped me understand how mistakes happen in code.
